# %% [markdown]
# # pyt5.py - LangGraph Orchestrator Visualization
# This notebook displays the graph structure of the multi-agent orchestrator.

# %%
import truststore
truststore.inject_into_ssl()

from dotenv import load_dotenv
load_dotenv()

# %%
from pyt5 import orchestrator

# %% [markdown]
# ## Mermaid Diagram
# Copy the output below and paste into [mermaid.live](https://mermaid.live) to visualize.

# %%
print(orchestrator.get_graph().draw_mermaid())

# %% [markdown]
# ## ASCII Graph

# %%
orchestrator.get_graph().print_ascii()

# %% [markdown]
# ## PNG Image (requires grandalf)
# Install: `uv pip install grandalf`

# %%
from IPython.display import Image, display

try:
    png_data = orchestrator.get_graph().draw_mermaid_png()
    display(Image(png_data))
except Exception as e:
    print(f"PNG rendering failed: {e}")
    print("Falling back to Mermaid text output:")
    print(orchestrator.get_graph().draw_mermaid())
